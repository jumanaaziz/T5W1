# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('/content/Task (1) Dataset.csv')
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
df.shape
# Out:
# (12316, 32)

# %% [markdown]
# ### Handle Missing Values

# %%
df.tail()
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 12311                 NaN                Employee              2-5yr
# 12312   Elementary school                Employee             5-10yr
# 12313  Junior high school                Employee             5-10yr
# 12314  Junior high school                Employee         Above 10yr
# 12315  Junior high school                Employee             5-10yr
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 12311   Lorry (11?40Q)            Owner                     NaN  ...
# ...

# %%
df.sample(5)
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 901    19:47:00    Saturday              18-30        Female
# 11583  14:00:00    Saturday              18-30          Male
# 2705   17:46:00     Tuesday              18-30          Male
# 8510   14:15:00      Monday            Over 51          Male
# 11564  15:33:00     Tuesday              31-50          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 901    Junior high school                Employee             5-10yr
# 11583  Junior high school                Employee         Above 10yr
# 2705    Elementary school                Employee             5-10yr
# 8510   Junior high school                Employee          Below 1yr
# 11564  Junior high school                   Owner             5-10yr
#
#            Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 901    Public (> 45 seats)            Owner              Above 10yr  ...
# ...

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
#removing columns
df.drop('Educational_level',axis=1, inplace=True)
df.drop('Type_of_vehicle',axis=1, inplace=True)
df.drop('Service_year_of_vehicle',axis=1, inplace=True)
df.drop('Defect_of_vehicle',axis=1, inplace=True)
df.drop('Work_of_casuality',axis=1, inplace=True)
df.drop('Fitness_of_casuality',axis=1, inplace=True)

# %%
df['Vehicle_driver_relation'].fillna(df['Vehicle_driver_relation'].mean(), inplace=True)
df['Educational_level'] = df['Educational_level'].fillna('Unknown')
df['Owner_of_vehicle'] = df['Owner_of_vehicle'].fillna('Unknown')
df['Area_accident_occured'] = df['Area_accident_occured'].fillna('Unknown')
df['Lanes_or_Medians'] = df['Lanes_or_Medians'].fillna('Unknown')
df['Road_allignment'] = df['Road_allignment'].fillna('Unknown')
df['Types_of_Junction'] = df['Types_of_Junction'].fillna('Unknown')
df['Road_surface_type'] = df['Road_surface_type'].fillna('Unknown')
df['Type_of_collision'] = df['Type_of_collision'].fillna('Unknown')
df['Vehicle_movement'] = df['Vehicle_movement'].fillna('Unknown')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-524109b33d3c> in <cell line: 1>()
# ----> 1 df['Vehicle_driver_relation'].fillna(df['Vehicle_driver_relation'].mean(), inplace=True)
#       2 df['Educational_level'] = df['Educational_level'].fillna('Unknown')
#       3 df['Owner_of_vehicle'] = df['Owner_of_vehicle'].fillna('Unknown')
#       4 df['Area_accident_occured'] = df['Area_accident_occured'].fillna('Unknown')
#       5 df['Lanes_or_Medians'] = df['Lanes_or_Medians'].fillna('Unknown')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11554             **kwargs,
#   11555         ):
# > 11556             return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11557
#   11558         setattr(cls, "mean", mean)
#
# ...

# %%
df.dtypes
# Out:
# Time                            object
# Day_of_week                     object
# Age_band_of_driver              object
# Sex_of_driver                   object
# Educational_level               object
# Vehicle_driver_relation        float64
# Driving_experience              object
# Owner_of_vehicle               float64
# Area_accident_occured           object
# Lanes_or_Medians                object
# Road_allignment                 object
# Types_of_Junction               object
# Road_surface_type               object
# Road_surface_conditions         object
# Light_conditions                object
# Weather_conditions              object
# Type_of_collision               object
# Number_of_vehicles_involved      int64
# Number_of_casualties           float64
# Vehicle_movement                object
# Casualty_class                  object
# Sex_of_casualty                 object
# Age_band_of_casualty            object
# Casualty_severity               object
# ...

# %%
df.isnull().sum()
# Out:
# Time                               0
# Day_of_week                        0
# Age_band_of_driver                 0
# Sex_of_driver                      0
# Educational_level                741
# Vehicle_driver_relation        12316
# Driving_experience               829
# Owner_of_vehicle               12316
# Area_accident_occured              0
# Lanes_or_Medians                 385
# Road_allignment                  142
# Types_of_Junction                887
# Road_surface_type                172
# Road_surface_conditions            0
# Light_conditions                   0
# Weather_conditions                 0
# Type_of_collision                155
# Number_of_vehicles_involved        0
# Number_of_casualties           12308
# Vehicle_movement                 308
# Casualty_class                     0
# Sex_of_casualty                    0
# Age_band_of_casualty               0
# Casualty_severity                  0
# Pedestrian_movement                0
# ...

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
df.describe()
#depend on what i see there is no inconsistents
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
df.dtypes
# Out:
# Time                            object
# Day_of_week                     object
# Age_band_of_driver              object
# Sex_of_driver                   object
# Educational_level               object
# Vehicle_driver_relation         object
# Driving_experience              object
# Owner_of_vehicle                object
# Area_accident_occured           object
# Lanes_or_Medians                object
# Road_allignment                 object
# Types_of_Junction               object
# Road_surface_type               object
# Road_surface_conditions         object
# Light_conditions                object
# Weather_conditions              object
# Type_of_collision               object
# Number_of_vehicles_involved      int64
# Number_of_casualties           float64
# Vehicle_movement                object
# Casualty_class                  object
# Sex_of_casualty                 object
# Age_band_of_casualty            object
# Casualty_severity               object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %%
#let number of vehicles str since we cannot give the avg
df['Number_of_vehicles_involved']=df['Number_of_vehicles_involved'].astype(str)

# %%
#function to remove split string and integer
def clean(column):
  return float(column.split()[0])

  df['Driving_experience']=df['Driving_experience'].apply(clean)
  df['Age_band_of_driver']=df['Age_band_of_driver'].apply(clean)
  df['Service_year_of_vehicle']=df['Service_year_of_vehicle'].apply(clean)

# %%
df.sample(5)
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 2268   12:30:00     Tuesday            Unknown          Male
# 1658   16:00:00   Wednesday            Over 51          Male
# 11266  15:10:00   Wednesday              31-50          Male
# 4710   20:48:00      Friday            Unknown        Female
# 8511   14:15:00      Monday            Over 51          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 2268   Junior high school                Employee             5-10yr
# 1658   Junior high school                Employee          Below 1yr
# 11266  Junior high school                Employee              1-2yr
# 4710    Elementary school                Employee              2-5yr
# 8511                  NaN                   Owner                NaN
#
#       Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 2268     Stationwagen            Owner              Above 10yr  ...
# ...

# %%
sns.boxplot(df['Age_band_of_driver'])
# Out:
# <Axes: ylabel='Age_band_of_driver'>

# %%
sns.boxplot(df['Driving_experience'])
# Out:
# <Axes: ylabel='Driving_experience'>

# %%
sns.boxplot(df['Type_of_vehicle'])
# Out:
# <Axes: ylabel='Type_of_vehicle'>

# %%
sns.boxplot(df['Vehicle_movement'])
# Out:
# <Axes: ylabel='Vehicle_movement'>

# %%
#remove outlier from colunm vehicle movement using IQR
#i forgot how to calculate the function
def removing(df, column):
  df[column] = pd.to_numeric(df[column], errors='coerce')
  Q1= df[column].quantile(0.25)
  Q3 = df[column].quantile(0.75)
  IQR = Q3 - Q1
  lower_bound = Q1 - 1.5 * IQR
  upper_bound = Q3 + 1.5 * IQR
  return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

df=removing(df, 'Vehicle_movement')

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.describe()
# Out:
#        Number_of_casualties
# count          12316.000000
# mean               1.548149
# std                1.007179
# min                1.000000
# 25%                1.000000
# 50%                1.000000
# 75%                2.000000
# max                8.000000

# %%
df['Number_of_casualties'].value_counts()
# Out:
# Number_of_casualties
# 8397.0    1
# 2290.0    1
# 909.0     1
# 394.0     1
# 207.0     1
# 89.0      1
# 22.0      1
# 8.0       1
# Name: count, dtype: int64

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
#correlation
numeric=df.select_dtypes(include=['number'])
matrix=numeric.corr()
matrix
# Out:
#                              Number_of_vehicles_involved  Number_of_casualties
# Number_of_vehicles_involved                     1.000000              0.298817
# Number_of_casualties                            0.298817              1.000000

# %%
sns.heatmap(matrix, annot=True)
plt.show()

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
sns.displot(x=df['Age_band_of_casualty'])
plt.title('Age')
plt.xlabel('Age band of casualty')
plt.show()

# %%
sns.displot(x=df['Age_band_of_driver'])
plt.title('Age')
plt.xlabel('Age band of driver')
plt.show()

# %%
sns.displot(x=df['Type_of_vehicle'])
plt.title('types')
plt.xlabel('type of vehicles')
plt.show()

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
df.plot.scatter(x='Age_band_of_driver', y='Accident_severity')
plt.show()

# %%
#more charts with differnet variables

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
#line chart
df['Driving_experience'].value_counts().sort_index().plot.line()
# Out:
# <Axes: xlabel='Driving_experience'>

# %%
#line chart
df['Time'].value_counts().sort_index().plot.line()
# Out:
# <Axes: xlabel='Time'>

# %%
#relation between

df['Area_accident_occured'] = df['Area_accident_occured'].astype(str)
df['Day_of_week'] = df['Day_of_week'].astype(str)
df.plot.scatter(x='Day_of_week', y='Area_accident_occured')
# Out:
# <Axes: xlabel='Day_of_week', ylabel='Area_accident_occured'>

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %% [markdown]
# as we can see i dont know why the chart not work with me but i was looking for gathering info like: what is the relation between area of accident and the day? which day will the area be crowded on? and which time mont accidents happen? who make accidents more females or males? does the driving  experience effect as well? and how?
